# %%
# LOADING LIBRARIES
from os import *
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

from collections import Counter
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import RandomOverSampler
from lightgbm import LGBMClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn import tree
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import SGDClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
import xgboost as xgb
import lightgbm as lgb
from sklearn.model_selection import cross_val_score
# Out:
# Using TensorFlow backend.

# %%
# CHECK DIRECTORY AND SET DIRECTORY
getcwd()
chdir('C:\\Users\\My guest\\Desktop\\project 2')
getcwd()
# Out:
# 'C:\\Users\\My guest\\Desktop\\project 2'

# %%
# read data set
train=pd.read_csv('train.csv')
test=pd.read_csv('test.csv')

# %%
train.shape,test.shape
# Out:
# ((200000, 202), (200000, 201))

# %%
train.info(),test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Columns: 202 entries, ID_code to var_199
# dtypes: float64(200), int64(1), object(1)
# memory usage: 308.2+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Columns: 201 entries, ID_code to var_199
# dtypes: float64(200), object(1)
# memory usage: 306.7+ MB
# (None, None)

# %%
#droping id_code colum from both the data set
test=test.drop('ID_code',axis=1)
train=train.drop('ID_code',axis=1)

# %%
# changing the data type of target column of train data set
train.target=train.target.astype('category')

# %%
# lets do some visulisation of data
#befor that disciptive analysis
train.describe()
# Out:
#                var_0          var_1          var_2          var_3  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean       10.679914      -1.627622      10.715192       6.796529
# std         3.040051       4.050044       2.640894       2.043319
# min         0.408400     -15.043400       2.117100      -0.040200
# 25%         8.453850      -4.740025       8.722475       5.254075
# 50%        10.524750      -1.608050      10.580000       6.825000
# 75%        12.758200       1.358625      12.516700       8.324100
# max        20.315000      10.376800      19.353000      13.188300
#
#                var_4          var_5          var_6          var_7  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean       11.078333      -5.065317       5.408949      16.545850
# std         1.623150       7.863267       0.866607       3.418076
# min         5.074800     -32.562600       2.347300       5.349700
# 25%         9.883175     -11.200350       4.767700      13.943800
# 50%        11.108250      -4.833150       5.385100      16.456800
# 75%        12.261125       0.924800       6.003000      19.102900
# max        16.671400      17.251600       8.447700      27.691800
#
#                var_8          var_9  ...        var_190        var_191  \
# count  200000.000000  200000.000000  ...  200000.000000  200000.000000
# mean        0.284162       7.567236  ...       3.234440       7.438408
# std         3.332634       1.235070  ...       4.559922       3.023272
# min       -10.505500       3.970500  ...     -14.093300      -2.691700
# 25%        -2.317800       6.618800  ...      -0.058825       5.157400
# 50%         0.393700       7.629600  ...       3.203600       7.347750
# 75%         2.937900       8.584425  ...       6.406200       9.512525
# max        10.151300      11.150600  ...      18.440900      16.716500
#
#              var_192        var_193        var_194        var_195  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        1.927839       3.331774      17.993784      -0.142088
# std         1.478423       3.992030       3.135162       1.429372
# min        -3.814500     -11.783400       8.694400      -5.261000
# 25%         0.889775       0.584600      15.629800      -1.170700
# 50%         1.901300       3.396350      17.957950      -0.172700
# 75%         2.949500       6.205800      20.396525       0.829600
# max         8.402400      18.281800      27.928800       4.272900
#
#              var_196        var_197        var_198        var_199
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        2.303335       8.908158      15.870720      -3.326537
# std         5.454369       0.921625       3.010945      10.438015
# min       -14.209600       5.960600       6.299300     -38.852800
# 25%        -1.946925       8.252800      13.829700     -11.208475
# 50%         2.408900       8.888200      15.934050      -2.819550
# 75%         6.556725       9.593300      18.064725       4.836800
# max        18.321500      12.000400      26.079100      28.500700
#
# [8 rows x 200 columns]

# %%
test.describe()
# Out:
#                var_0          var_1          var_2          var_3  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean       10.658737      -1.624244      10.707452       6.788214
# std         3.036716       4.040509       2.633888       2.052724
# min         0.188700     -15.043400       2.355200      -0.022400
# 25%         8.442975      -4.700125       8.735600       5.230500
# 50%        10.513800      -1.590500      10.560700       6.822350
# 75%        12.739600       1.343400      12.495025       8.327600
# max        22.323400       9.385100      18.714100      13.142000
#
#                var_4          var_5          var_6          var_7  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean       11.076399      -5.050558       5.415164      16.529143
# std         1.616456       7.869293       0.864686       3.424482
# min         5.484400     -27.767000       2.216400       5.713700
# 25%         9.891075     -11.201400       4.772600      13.933900
# 50%        11.099750      -4.834100       5.391600      16.422700
# 75%        12.253400       0.942575       6.005800      19.094550
# max        16.037100      17.253700       8.302500      28.292800
#
#                var_8          var_9  ...        var_190        var_191  \
# count  200000.000000  200000.000000  ...  200000.000000  200000.000000
# mean        0.277135       7.569407  ...       3.189766       7.458269
# std         3.333375       1.231865  ...       4.551239       3.025189
# min        -9.956000       4.243300  ...     -14.093300      -2.407000
# 25%        -2.303900       6.623800  ...      -0.095000       5.166500
# 50%         0.372000       7.632000  ...       3.162400       7.379000
# 75%         2.930025       8.584825  ...       6.336475       9.531100
# max         9.665500      11.003600  ...      20.359000      16.716500
#
#              var_192        var_193        var_194        var_195  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        1.925944       3.322016      17.996967      -0.133657
# std         1.479966       3.995599       3.140652       1.429678
# min        -3.340900     -11.413100       9.382800      -4.911900
# 25%         0.882975       0.587600      15.634775      -1.160700
# 50%         1.892600       3.428500      17.977600      -0.162000
# 75%         2.956000       6.174200      20.391725       0.837900
# max         8.005000      17.632600      27.947800       4.545400
#
#              var_196        var_197        var_198        var_199
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        2.290899       8.912428      15.869184      -3.246342
# std         5.446346       0.920904       3.008717      10.398589
# min       -13.944200       6.169600       6.584000     -39.457800
# 25%        -1.948600       8.260075      13.847275     -11.124000
# 50%         2.403600       8.892800      15.943400      -2.725950
# 75%         6.519800       9.595900      18.045200       4.935400
# max        15.920700      12.275800      26.538400      27.907400
#
# [8 rows x 200 columns]

# %%
train.target.describe()
# Out:
# count     200000
# unique         2
# top            0
# freq      179902
# Name: target, dtype: int64

# %%
# checking the training data for imbalance 
count_classes = pd.value_counts(train.target)
print(count_classes)
count_classes.plot(kind= 'bar',rot=1)
# Out:
# 0    179902
# 1     20098
# Name: target, dtype: int64

# %%
# Data to plot
labels = 'zeros', 'ones'
sizes = [179902,20098]
colors = ['gold', 'yellowgreen']
explode = (0.1, 0)  # explode 1st slice

# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.show()

# %%
columns=test.columns
print(columns)
for i in columns:
    #plt.figure()
    plt.hist(train[i])
    plt.show()
# Out:
# Index(['var_0', 'var_1', 'var_2', 'var_3', 'var_4', 'var_5', 'var_6', 'var_7',
#        'var_8', 'var_9',
#        ...
#        'var_190', 'var_191', 'var_192', 'var_193', 'var_194', 'var_195',
#        'var_196', 'var_197', 'var_198', 'var_199'],
#       dtype='object', length=200)

# %%
#missing value analysis
train.isna().sum().sum()
test.isna().sum().sum()
# there are no missing values in both the data sets
# Out:
# 0

# %%
train_input=train.drop('target',axis=1) 
columns=train_input.columns
columns
# Out:
# Index(['var_0', 'var_1', 'var_2', 'var_3', 'var_4', 'var_5', 'var_6', 'var_7',
#        'var_8', 'var_9',
#        ...
#        'var_190', 'var_191', 'var_192', 'var_193', 'var_194', 'var_195',
#        'var_196', 'var_197', 'var_198', 'var_199'],
#       dtype='object', length=200)

# %%
outliers=0
for i in columns:
    q75=np.percentile(train[i],75)
    q25=np.percentile(train[i],25)
    iqr=q75-q25
    minimum=q25-(iqr*1.5)
    maximum=q75+(iqr*1.5)
    print('q75=',q75,'q25=',q25,'iqr=',iqr,'minimum=',minimum,'maximum=',maximum)
    outlier=(train[i]>maximum).sum()+(train[i]<minimum).sum()
    print('no. of outlier in ',i,'is',outlier)
    outliers=outliers+outlier
# Out:
# q75= 12.7582 q25= 8.453850000000001 iqr= 4.3043499999999995 minimum= 1.9973250000000018 maximum= 19.214725
# no. of outlier in  var_0 is 104
# q75= 1.358625 q25= -4.740025 iqr= 6.09865 minimum= -13.888000000000002 maximum= 10.5066
# no. of outlier in  var_1 is 6
# q75= 12.5167 q25= 8.722475 iqr= 3.794225000000001 minimum= 3.031137499999998 maximum= 18.208037500000003
# no. of outlier in  var_2 is 49
# q75= 8.3241 q25= 5.254075 iqr= 3.0700249999999993 minimum= 0.6490375000000013 maximum= 12.9291375
# no. of outlier in  var_3 is 22
# q75= 12.261125000000002 q25= 9.883175 iqr= 2.377950000000002 minimum= 6.316249999999997 maximum= 15.828050000000005
# no. of outlier in  var_4 is 76
# q75= 0.9248 q25= -11.20035 iqr= 12.12515 minimum= -29.388075 maximum= 19.112525
# no. of outlier in  var_5 is 4
# q75= 6.002999999999999 q25= 4.7677 iqr= 1.2352999999999996 minimum= 2.91475 maximum= 7.855949999999998
# no. of outlier in  var_6 is 113
# q75= 19.1029 q25= 13.9438 iqr= 5.159100000000002 minimum= 6.205149999999996 maximum= 26.841550000000005
# no. of outlier in  var_7 is 19
# q75= 2.9379 q25= -2.3178 iqr= 5.2557 minimum= -10.20135 maximum= 10.821449999999999
# no. of outlier in  var_8 is 2
# q75= 8.584425 q25= 6.6188 iqr= 1.9656249999999993 minimum= 3.6703625000000013 maximum= 11.532862499999998
# no. of outlier in  var_9 is 0
# q75= 4.382925 q25= -3.5949500000000003 iqr= 7.977875000000001 minimum= -15.561762500000002 maximum= 16.349737500000003
# no. of outlier in  var_10 is 125
# q75= 0.8528249999999999 q25= -7.5106 iqr= 8.363425 minimum= -20.0557375 maximum= 13.397962499999998
# no. of outlier in  var_11 is 309
# q75= 14.1642 q25= 13.894 iqr= 0.2701999999999991 minimum= 13.488700000000001 maximum= 14.569499999999998
# no. of outlier in  var_12 is 39
# q75= 12.274775 q25= 5.0728 iqr= 7.201975 minimum= -5.7301625 maximum= 23.077737499999998
# no. of outlier in  var_13 is 1
# q75= 9.270425 q25= 5.781875 iqr= 3.488549999999999 minimum= 0.549050000000002 maximum= 14.503249999999998
# no. of outlier in  var_14 is 2
# q75= 14.8745 q25= 14.2628 iqr= 0.611699999999999 minimum= 13.345250000000002 maximum= 15.792049999999998
# no. of outlier in  var_15 is 22
# q75= 11.0559 q25= 7.452275 iqr= 3.603624999999999 minimum= 2.0468375000000014 maximum= 16.4613375
# no. of outlier in  var_16 is 68
# q75= -0.810775 q25= -10.476225000000001 iqr= 9.665450000000002 minimum= -24.974400000000003 maximum= 13.687400000000004
# no. of outlier in  var_17 is 221
# q75= 21.013325000000002 q25= 9.17795 iqr= 11.835375000000003 minimum= -8.575112500000007 maximum= 38.76638750000001
# no. of outlier in  var_18 is 11
# q75= 18.4333 q25= 6.2764750000000005 iqr= 12.156824999999998 minimum= -11.958762499999995 maximum= 36.6685375
# no. of outlier in  var_19 is 1
# q75= 17.8794 q25= 8.6278 iqr= 9.2516 minimum= -5.249599999999999 maximum= 31.7568
# no. of outlier in  var_20 is 1
# q75= 23.089050000000004 q25= 11.550999999999998 iqr= 11.538050000000005 minimum= -5.75607500000001 maximum= 40.39612500000001
# no. of outlier in  var_21 is 275
# q75= 6.2932 q25= 2.1824 iqr= 4.110799999999999 minimum= -3.983799999999999 maximum= 12.459399999999999
# no. of outlier in  var_22 is 289
# q75= 3.4038 q25= 2.6341 iqr= 0.7696999999999998 minimum= 1.4795500000000004 maximum= 4.55835
# no. of outlier in  var_23 is 90
# q75= 13.4796 q25= 7.6129999999999995 iqr= 5.8666 minimum= -1.1869000000000014 maximum= 22.2795
# no. of outlier in  var_24 is 4
# q75= 13.8637 q25= 13.4564 iqr= 0.40729999999999933 minimum= 12.845450000000001 maximum= 14.474649999999999
# no. of outlier in  var_25 is 241
# q75= -0.0902 q25= -8.321725 iqr= 8.231525000000001 minimum= -20.6690125 maximum= 12.257087500000003
# no. of outlier in  var_26 is 186
# q75= 0.015624999999999998 q25= -2.3079 iqr= 2.323525 minimum= -5.7931875 maximum= 3.5009125
# no. of outlier in  var_27 is 3
# q75= 6.0937 q25= 4.9921 iqr= 1.1016000000000004 minimum= 3.3396999999999992 maximum= 7.7461
# no. of outlier in  var_28 is 193
# q75= 6.798925 q25= 3.1717 iqr= 3.6272249999999997 minimum= -2.2691375 maximum= 12.2397625
# no. of outlier in  var_29 is 144
# q75= -1.44345 q25= -13.766175 iqr= 12.322725 minimum= -32.250262500000005 maximum= 17.040637500000003
# no. of outlier in  var_30 is 12
# q75= 11.885 q25= 8.87 iqr= 3.0150000000000006 minimum= 4.347499999999998 maximum= 16.4075
# no. of outlier in  var_31 is 637
# q75= 1.4691 q25= -2.5008749999999997 iqr= 3.969975 minimum= -8.4558375 maximum= 7.4240625
# no. of outlier in  var_32 is 2
# q75= 18.097125000000002 q25= 11.4563 iqr= 6.640825000000001 minimum= 1.4950624999999977 maximum= 28.058362500000005
# no. of outlier in  var_33 is 4
# q75= 11.8444 q25= 11.0323 iqr= 0.8121000000000009 minimum= 9.814149999999998 maximum= 13.062550000000002
# no. of outlier in  var_34 is 10
# q75= 7.487725 q25= 0.116975 iqr= 7.37075 minimum= -10.93915 maximum= 18.54385
# no. of outlier in  var_35 is 198
# q75= 4.4604 q25= -0.007124999999999999 iqr= 4.467525 minimum= -6.7084125000000006 maximum= 11.1616875
# no. of outlier in  var_36 is 178
# q75= 7.5424 q25= 4.125475 iqr= 3.416925 minimum= -0.9999125000000006 maximum= 12.6677875
# no. of outlier in  var_37 is 1
# q75= 13.598925000000001 q25= 7.59105 iqr= 6.007875000000001 minimum= -1.4207625000000013 maximum= 22.610737500000003
# no. of outlier in  var_38 is 502
# q75= 3.637825 q25= -2.1995 iqr= 5.837325 minimum= -10.9554875 maximum= 12.3938125
# no. of outlier in  var_39 is 158
# q75= -0.8808750000000001 q25= -12.831824999999998 iqr= 11.950949999999999 minimum= -30.758249999999997 maximum= 17.04555
# no. of outlier in  var_40 is 48
# q75= 13.7548 q25= 4.519575 iqr= 9.235225 minimum= -9.3332625 maximum= 27.6076375
# no. of outlier in  var_41 is 0
# q75= 11.7569 q25= 10.7132 iqr= 1.0436999999999994 minimum= 9.147650000000002 maximum= 13.32245
# no. of outlier in  var_42 is 32
# q75= 11.8046 q25= 11.3438 iqr= 0.46080000000000076 minimum= 10.6526 maximum= 12.495800000000003
# no. of outlier in  var_43 is 17
# q75= 13.0873 q25= 5.31365 iqr= 7.773650000000001 minimum= -6.346825000000002 maximum= 24.747775000000004
# no. of outlier in  var_44 is 1208
# q75= 3.150525 q25= -28.7307 iqr= 31.881225 minimum= -76.5525375 maximum= 50.9723625
# no. of outlier in  var_45 is 41
# q75= 13.3183 q25= 9.24875 iqr= 4.069550000000001 minimum= 3.1444249999999974 maximum= 19.422625000000004
# no. of outlier in  var_46 is 268
# q75= -4.244525 q25= -20.654525 iqr= 16.41 minimum= -45.269525 maximum= 20.370475000000003
# no. of outlier in  var_47 is 2
# q75= 23.028650000000003 q25= 6.351975 iqr= 16.676675000000003 minimum= -18.663037500000005 maximum= 48.04366250000001
# no. of outlier in  var_48 is 95
# q75= 22.549049999999998 q25= 10.653474999999998 iqr= 11.895575 minimum= -7.189887499999999 maximum= 40.39241249999999
# no. of outlier in  var_49 is 7
# q75= 13.2345 q25= 12.269 iqr= 0.9655000000000005 minimum= 10.82075 maximum= 14.682750000000002
# no. of outlier in  var_50 is 222
# q75= 19.38565 q25= 7.267625000000001 iqr= 12.118024999999998 minimum= -10.909412499999997 maximum= 37.562687499999996
# no. of outlier in  var_51 is 42
# q75= 0.94435 q25= -6.065025 iqr= 7.009375 minimum= -16.5790875 maximum= 11.458412500000001
# no. of outlier in  var_52 is 353
# q75= 6.5429 q25= 5.4356 iqr= 1.1073000000000004 minimum= 3.7746499999999994 maximum= 8.203850000000001
# no. of outlier in  var_53 is 27
# q75= 7.401825 q25= -5.147625 iqr= 12.54945 minimum= -23.9718 maximum= 26.226
# no. of outlier in  var_54 is 38
# q75= 17.086624999999998 q25= 8.1639 iqr= 8.922724999999998 minimum= -5.220187499999996 maximum= 30.470712499999994
# no. of outlier in  var_55 is 0
# q75= 19.2897 q25= 14.097875 iqr= 5.191825 minimum= 6.310137500000001 maximum= 27.0774375
# no. of outlier in  var_56 is 254
# q75= 6.845 q25= 5.6875 iqr= 1.1574999999999998 minimum= 3.9512500000000004 maximum= 8.581249999999999
# no. of outlier in  var_57 is 145
# q75= 6.2097 q25= 0.1835 iqr= 6.026199999999999 minimum= -8.855799999999999 maximum= 15.248999999999999
# no. of outlier in  var_58 is 401
# q75= 9.566525 q25= 8.3124 iqr= 1.2541250000000002 minimum= 6.4312125 maximum= 11.447712500000002
# no. of outlier in  var_59 is 53
# q75= 15.1165 q25= 8.91275 iqr= 6.203749999999999 minimum= -0.3928749999999983 maximum= 24.422125
# no. of outlier in  var_60 is 5
# q75= -3.2254499999999995 q25= -20.901725 iqr= 17.676275 minimum= -47.4161375 maximum= 23.2889625
# no. of outlier in  var_61 is 56
# q75= 2.2282 q25= -0.5724 iqr= 2.8006 minimum= -4.773300000000001 maximum= 6.429100000000001
# no. of outlier in  var_62 is 432
# q75= 3.0203 q25= -1.5887 iqr= 4.609 minimum= -8.5022 maximum= 9.9338
# no. of outlier in  var_63 is 187
# q75= 7.4906 q25= 5.2935 iqr= 2.1971 minimum= 1.9978500000000001 maximum= 10.786249999999999
# no. of outlier in  var_64 is 27
# q75= 3.7392 q25= -1.7028 iqr= 5.442 minimum= -9.8658 maximum= 11.9022
# no. of outlier in  var_65 is 251
# q75= 6.5862 q25= 4.9738 iqr= 1.6124 minimum= 2.5551999999999997 maximum= 9.0048
# no. of outlier in  var_66 is 152
# q75= 17.03765 q25= 6.7532 iqr= 10.28445 minimum= -8.673475 maximum= 32.464325
# no. of outlier in  var_67 is 465
# q75= 5.0241 q25= 5.013999999999999 iqr= 0.010100000000000442 minimum= 4.998849999999999 maximum= 5.039250000000001
# no. of outlier in  var_68 is 96
# q75= -0.49887500000000007 q25= -6.336625 iqr= 5.83775 minimum= -15.09325 maximum= 8.25775
# no. of outlier in  var_69 is 15
# q75= 33.63315 q25= 15.256625 iqr= 18.376525 minimum= -12.308162500000002 maximum= 61.1979375
# no. of outlier in  var_70 is 6
# q75= 0.8644 q25= 0.4723 iqr= 0.39209999999999995 minimum= -0.11584999999999995 maximum= 1.45255
# no. of outlier in  var_71 is 47
# q75= 3.5107 q25= -2.1971 iqr= 5.7078 minimum= -10.7588 maximum= 12.0724
# no. of outlier in  var_72 is 128
# q75= 25.207125 q25= 14.097275 iqr= 11.109850000000002 minimum= -2.5675000000000026 maximum= 41.871900000000004
# no. of outlier in  var_73 is 22
# q75= 29.6207 q25= 9.595975 iqr= 20.024725 minimum= -20.4411125 maximum= 59.6577875
# no. of outlier in  var_74 is 313
# q75= 21.432225000000003 q25= 12.480974999999999 iqr= 8.951250000000003 minimum= -0.9459000000000071 maximum= 34.85910000000001
# no. of outlier in  var_75 is 11
# q75= 11.8188 q25= 0.5963 iqr= 11.2225 minimum= -16.237450000000003 maximum= 28.65255
# no. of outlier in  var_76 is 233
# q75= 22.0411 q25= 16.0147 iqr= 6.026399999999999 minimum= 6.975100000000003 maximum= 31.0807
# no. of outlier in  var_77 is 0
# q75= 6.8672 q25= 3.817275 iqr= 3.0499250000000004 minimum= -0.7576125000000009 maximum= 11.442087500000001
# no. of outlier in  var_78 is 2
# q75= 15.3831 q25= 13.3754 iqr= 2.0077 minimum= 10.363850000000001 maximum= 18.39465
# no. of outlier in  var_79 is 0
# q75= 11.449124999999999 q25= 0.694475 iqr= 10.754649999999998 minimum= -15.437499999999996 maximum= 27.581099999999996
# no. of outlier in  var_80 is 22
# q75= 16.3408 q25= 13.214775000000001 iqr= 3.1260250000000003 minimum= 8.525737500000002 maximum= 21.029837500000003
# no. of outlier in  var_81 is 169
# q75= 3.101725 q25= -10.00495 iqr= 13.106675 minimum= -29.6649625 maximum= 22.761737500000002
# no. of outlier in  var_82 is 2
# q75= 7.4499 q25= -5.1064 iqr= 12.5563 minimum= -23.94085 maximum= 26.28435
# no. of outlier in  var_83 is 6
# q75= 1.9867 q25= -7.216125 iqr= 9.202825 minimum= -21.0203625 maximum= 15.790937500000002
# no. of outlier in  var_84 is 38
# q75= 21.358849999999997 q25= 15.338574999999999 iqr= 6.020274999999998 minimum= 6.308162500000002 maximum= 30.389262499999994
# no. of outlier in  var_85 is 4
# q75= 11.158375000000001 q25= 0.40755 iqr= 10.750825 minimum= -15.718687500000001 maximum= 27.2846125
# no. of outlier in  var_86 is 152
# q75= 15.433225 q25= 7.247175 iqr= 8.18605 minimum= -5.0318999999999985 maximum= 27.7123
# no. of outlier in  var_87 is 131
# q75= 10.567025000000001 q25= 6.918775 iqr= 3.648250000000001 minimum= 1.4463999999999988 maximum= 16.0394
# no. of outlier in  var_88 is 30
# q75= 6.1462 q25= 1.1405 iqr= 5.0057 minimum= -6.368049999999999 maximum= 13.65475
# no. of outlier in  var_89 is 84
# q75= -6.409375000000001 q25= -26.6656 iqr= 20.256225 minimum= -57.0499375 maximum= 23.9749625
# no. of outlier in  var_90 is 9
# q75= 7.1014 q25= 6.8699 iqr= 0.2314999999999996 minimum= 6.5226500000000005 maximum= 7.448649999999999
# no. of outlier in  var_91 is 22
# q75= 15.840225 q25= 9.6703 iqr= 6.169925000000001 minimum= 0.41541249999999685 maximum= 25.095112500000003
# no. of outlier in  var_92 is 41
# q75= 10.9449 q25= 10.1956 iqr= 0.7492999999999999 minimum= 9.071650000000002 maximum= 12.068850000000001
# no. of outlier in  var_93 is 889
# q75= 13.0891 q25= 8.828 iqr= 4.261100000000001 minimum= 2.4363499999999982 maximum= 19.48075
# no. of outlier in  var_94 is 0
# q75= 0.3291 q25= -0.5274 iqr= 0.8565 minimum= -1.81215 maximum= 1.61385
# no. of outlier in  var_95 is 162
# q75= 20.819375 q25= 7.796950000000001 iqr= 13.022425 minimum= -11.7366875 maximum= 40.353012500000006
# no. of outlier in  var_96 is 6
# q75= 28.158974999999998 q25= 8.919525 iqr= 19.239449999999998 minimum= -19.939649999999997 maximum= 57.01814999999999
# no. of outlier in  var_97 is 8
# q75= 2.2609 q25= 1.267675 iqr= 0.9932249999999998 minimum= -0.2221624999999996 maximum= 3.7507374999999996
# no. of outlier in  var_98 is 172
# q75= 0.5285 q25= -2.1062 iqr= 2.6346999999999996 minimum= -6.058249999999999 maximum= 4.480549999999999
# no. of outlier in  var_99 is 85
# q75= 0.1321 q25= -13.1987 iqr= 13.3308 minimum= -33.194900000000004 maximum= 20.128300000000003
# no. of outlier in  var_100 is 176
# q75= 17.250225 q25= 9.6398 iqr= 7.610425000000001 minimum= -1.7758375000000033 maximum= 28.665862500000003
# no. of outlier in  var_101 is 0
# q75= 28.682225000000003 q25= 16.047974999999997 iqr= 12.634250000000005 minimum= -2.9034000000000084 maximum= 47.63360000000001
# no. of outlier in  var_102 is 92
# q75= 1.7054 q25= 1.4289 iqr= 0.27649999999999997 minimum= 1.01415 maximum= 2.1201499999999998
# no. of outlier in  var_103 is 37
# q75= 12.9021 q25= 10.0979 iqr= 2.8042000000000016 minimum= 5.891599999999997 maximum= 17.108400000000003
# no. of outlier in  var_104 is 325
# q75= 4.8222 q25= 3.6396 iqr= 1.1825999999999994 minimum= 1.865700000000001 maximum= 6.596099999999999
# no. of outlier in  var_105 is 572
# q75= 9.9289 q25= 7.2823 iqr= 2.6466000000000003 minimum= 3.3124 maximum= 13.898800000000001
# no. of outlier in  var_106 is 397
# q75= 23.3486 q25= 12.168075000000002 iqr= 11.180525 minimum= -4.6027124999999955 maximum= 40.1193875
# no. of outlier in  var_107 is 88
# q75= 14.3618 q25= 14.0989 iqr= 0.26290000000000013 minimum= 13.704550000000001 maximum= 14.756150000000002
# no. of outlier in  var_108 is 0
# q75= 21.8529 q25= 15.107175000000002 iqr= 6.745725 minimum= 4.988587500000001 maximum= 31.971487500000002
# no. of outlier in  var_109 is 1
# q75= 8.104325 q25= 2.817475 iqr= 5.286849999999999 minimum= -5.112799999999999 maximum= 16.034599999999998
# no. of outlier in  var_110 is 470
# q75= 7.0803 q25= 5.5101 iqr= 1.5701999999999998 minimum= 3.1548000000000007 maximum= 9.4356
# no. of outlier in  var_111 is 80
# q75= 4.5774 q25= 2.092675 iqr= 2.484725 minimum= -1.6344125000000003 maximum= 8.3044875
# no. of outlier in  var_112 is 14
# q75= 11.5962 q25= 4.80325 iqr= 6.792949999999999 minimum= -5.386175 maximum= 21.785625
# no. of outlier in  var_113 is 1
# q75= 3.8119 q25= 2.388775 iqr= 1.4231250000000002 minimum= 0.2540874999999998 maximum= 5.9465875
# no. of outlier in  var_114 is 49
# q75= 4.1215 q25= 0.3997 iqr= 3.7218 minimum= -5.183 maximum= 9.7042
# no. of outlier in  var_115 is 177
# q75= 3.6651 q25= 1.171875 iqr= 2.493225 minimum= -2.5679624999999997 maximum= 7.404937499999999
# no. of outlier in  var_116 is 16
# q75= 25.780825 q25= 6.3735 iqr= 19.407325 minimum= -22.7374875 maximum= 54.8918125
# no. of outlier in  var_117 is 107
# q75= 0.9718 q25= -11.58785 iqr= 12.55965 minimum= -30.427325 maximum= 19.811275000000002
# no. of outlier in  var_118 is 228
# q75= 6.0984 q25= -0.16197499999999998 iqr= 6.260375 minimum= -9.5525375 maximum= 15.4889625
# no. of outlier in  var_119 is 4
# q75= 33.105275000000006 q25= 15.696275 iqr= 17.409000000000006 minimum= -10.417225000000009 maximum= 59.218775000000015
# no. of outlier in  var_120 is 254
# q75= 12.619425000000001 q25= 9.9964 iqr= 2.623025000000002 minimum= 6.061862499999997 maximum= 16.553962500000004
# no. of outlier in  var_121 is 13
# q75= 5.0917 q25= -2.5652 iqr= 7.6569 minimum= -14.050550000000001 maximum= 16.57705
# no. of outlier in  var_122 is 24
# q75= 11.734749999999998 q25= 2.81705 iqr= 8.917699999999998 minimum= -10.559499999999998 maximum= 25.111299999999996
# no. of outlier in  var_123 is 23
# q75= 6.1922 q25= 2.3536 iqr= 3.8385999999999996 minimum= -3.404299999999999 maximum= 11.950099999999999
# no. of outlier in  var_124 is 498
# q75= 12.7181 q25= 12.2454 iqr= 0.4726999999999997 minimum= 11.53635 maximum= 13.42715
# no. of outlier in  var_125 is 188
# q75= 13.8117 q25= 12.6084 iqr= 1.2033000000000005 minimum= 10.803449999999998 maximum= 15.61665
# no. of outlier in  var_126 is 0
# q75= 3.293 q25= -1.502325 iqr= 4.795325 minimum= -8.6953125 maximum= 10.4859875
# no. of outlier in  var_127 is 2
# q75= 1.3517 q25= -3.580725 iqr= 4.932425 minimum= -10.9793625 maximum= 8.7503375
# no. of outlier in  var_128 is 15
# q75= 18.4804 q25= 12.514475000000001 iqr= 5.965924999999999 minimum= 3.565587500000003 maximum= 27.429287499999997
# no. of outlier in  var_129 is 96
# q75= 12.8767 q25= 11.6193 iqr= 1.2573999999999987 minimum= 9.733200000000004 maximum= 14.762799999999999
# no. of outlier in  var_130 is 15
# q75= 0.9009999999999999 q25= 0.2078 iqr= 0.6931999999999999 minimum= -0.8319999999999999 maximum= 1.9407999999999999
# no. of outlier in  var_131 is 6
# q75= 8.911425000000001 q25= 6.724375 iqr= 2.187050000000001 minimum= 3.4437999999999986 maximum= 12.192000000000004
# no. of outlier in  var_132 is 39
# q75= 7.0708 q25= 6.5435 iqr= 0.5273000000000003 minimum= 5.752549999999999 maximum= 7.861750000000001
# no. of outlier in  var_133 is 589
# q75= -0.1788 q25= -9.6257 iqr= 9.4469 minimum= -23.79605 maximum= 13.991549999999998
# no. of outlier in  var_134 is 1
# q75= 1.12595 q25= -9.9571 iqr= 11.08305 minimum= -26.581675 maximum= 17.750525
# no. of outlier in  var_135 is 27
# q75= 31.042425 q25= 14.9339 iqr= 16.108525 minimum= -9.2288875 maximum= 55.2052125
# no. of outlier in  var_136 is 2
# q75= 24.426025 q25= 10.65655 iqr= 13.769475 minimum= -9.9976625 maximum= 45.080237499999996
# no. of outlier in  var_137 is 0
# q75= 4.391225 q25= -2.011825 iqr= 6.40305 minimum= -11.6164 maximum= 13.995800000000001
# no. of outlier in  var_138 is 323
# q75= 13.232524999999999 q25= 2.387575 iqr= 10.844949999999999 minimum= -13.87985 maximum= 29.49995
# no. of outlier in  var_139 is 190
# q75= 7.078525000000001 q25= -0.1217 iqr= 7.2002250000000005 minimum= -10.922037500000002 maximum= 17.878862500000004
# no. of outlier in  var_140 is 129
# q75= 8.192425 q25= -2.153725 iqr= 10.34615 minimum= -17.67295 maximum= 23.71165
# no. of outlier in  var_141 is 1
# q75= 16.073925 q25= 7.9 iqr= 8.173924999999999 minimum= -4.360887499999999 maximum= 28.334812499999998
# no. of outlier in  var_142 is 148
# q75= 14.461049999999998 q25= 10.3112 iqr= 4.149849999999999 minimum= 4.086425000000001 maximum= 20.685824999999998
# no. of outlier in  var_143 is 109
# q75= 9.315 q25= 7.968075 iqr= 1.3469249999999997 minimum= 5.947687500000001 maximum= 11.3353875
# no. of outlier in  var_144 is 58
# q75= 7.676925 q25= 1.885875 iqr= 5.79105 minimum= -6.800700000000001 maximum= 16.363500000000002
# no. of outlier in  var_145 is 15
# q75= 12.113225000000002 q25= 8.6469 iqr= 3.466325000000001 minimum= 3.4474124999999987 maximum= 17.312712500000004
# no. of outlier in  var_146 is 804
# q75= 2.028275 q25= -8.75145 iqr= 10.779725 minimum= -24.921037499999997 maximum= 18.1978625
# no. of outlier in  var_147 is 104
# q75= 4.1316 q25= 3.8536 iqr= 0.2779999999999996 minimum= 3.4366000000000008 maximum= 4.548599999999999
# no. of outlier in  var_148 is 263
# q75= 12.688225 q25= -1.9032 iqr= 14.591425 minimum= -23.7903375 maximum= 34.5753625
# no. of outlier in  var_149 is 383
# q75= 18.6825 q25= 14.9522 iqr= 3.7303000000000015 minimum= 9.356749999999998 maximum= 24.277950000000004
# no. of outlier in  var_150 is 15
# q75= 13.0576 q25= 7.0646 iqr= 5.993 minimum= -1.9248999999999992 maximum= 22.0471
# no. of outlier in  var_151 is 1
# q75= 9.8173 q25= 5.5679 iqr= 4.2494 minimum= -0.8061999999999996 maximum= 16.191399999999998
# no. of outlier in  var_152 is 331
# q75= 18.2639 q25= 15.232999999999999 iqr= 3.030900000000001 minimum= 10.686649999999997 maximum= 22.81025
# no. of outlier in  var_153 is 4
# q75= 10.76635 q25= 3.3399 iqr= 7.426449999999999 minimum= -7.799774999999999 maximum= 21.906025
# no. of outlier in  var_154 is 7
# q75= 1.8917499999999998 q25= -6.266025000000001 iqr= 8.157775 minimum= -18.5026875 maximum= 14.128412500000001
# no. of outlier in  var_155 is 239
# q75= 13.9293 q25= 12.4751 iqr= 1.4542000000000002 minimum= 10.2938 maximum= 16.110599999999998
# no. of outlier in  var_156 is 28
# q75= -0.9885750000000001 q25= -8.93995 iqr= 7.951375 minimum= -20.8670125 maximum= 10.938487499999999
# no. of outlier in  var_157 is 36
# q75= 23.875324999999997 q25= 12.1092 iqr= 11.766124999999997 minimum= -5.539987499999997 maximum= 41.52451249999999
# no. of outlier in  var_158 is 17
# q75= 13.094525 q25= 7.243525 iqr= 5.851000000000001 minimum= -1.5329750000000022 maximum= 21.871025000000003
# no. of outlier in  var_159 is 177
# q75= 32.62285 q25= 15.696125 iqr= 16.926724999999998 minimum= -9.693962499999996 maximum= 58.01293749999999
# no. of outlier in  var_160 is 3
# q75= 5.792000000000001 q25= 5.4705 iqr= 0.32150000000000034 minimum= 4.98825 maximum= 6.274250000000001
# no. of outlier in  var_161 is 35
# q75= 6.3712 q25= 4.3261 iqr= 2.0450999999999997 minimum= 1.2584500000000007 maximum= 9.438849999999999
# no. of outlier in  var_162 is 150
# q75= 14.6239 q25= 7.0296 iqr= 7.5943000000000005 minimum= -4.3618500000000004 maximum= 26.01535
# no. of outlier in  var_163 is 146
# q75= 1.3236 q25= -7.094025 iqr= 8.417625000000001 minimum= -19.720462500000004 maximum= 13.950037500000002
# no. of outlier in  var_164 is 1
# q75= 23.024025 q25= 15.74455 iqr= 7.2794750000000015 minimum= 4.825337499999998 maximum= 33.9432375
# no. of outlier in  var_165 is 70
# q75= 3.2415 q25= 2.699 iqr= 0.5425 minimum= 1.8852499999999999 maximum= 4.05525
# no. of outlier in  var_166 is 30
# q75= 1.3187250000000001 q25= -9.6431 iqr= 10.961825000000001 minimum= -26.0858375 maximum= 17.7614625
# no. of outlier in  var_167 is 279
# q75= 7.0200249999999995 q25= 2.7032 iqr= 4.316825 minimum= -3.7720374999999997 maximum= 13.495262499999999
# no. of outlier in  var_168 is 286
# q75= 5.9054 q25= 5.3746 iqr= 0.5308000000000002 minimum= 4.5784 maximum= 6.701600000000001
# no. of outlier in  var_169 is 122
# q75= 3.0964 q25= -3.2585 iqr= 6.354900000000001 minimum= -12.79085 maximum= 12.62875
# no. of outlier in  var_170 is 413
# q75= 2.9568 q25= -4.72035 iqr= 7.677149999999999 minimum= -16.236075 maximum= 14.472525
# no. of outlier in  var_171 is 154
# q75= 25.907725 q25= 13.731774999999999 iqr= 12.17595 minimum= -4.5321500000000015 maximum= 44.17165
# no. of outlier in  var_172 is 397
# q75= 3.6199 q25= -5.009525 iqr= 8.629425 minimum= -17.9536625 maximum= 16.5640375
# no. of outlier in  var_173 is 131
# q75= 25.641225000000002 q25= 15.0646 iqr= 10.576625000000002 minimum= -0.800337500000003 maximum= 41.5061625
# no. of outlier in  var_174 is 34
# q75= 13.7455 q25= 9.3716 iqr= 4.373899999999999 minimum= 2.8107500000000023 maximum= 20.30635
# no. of outlier in  var_175 is 2
# q75= 2.7044 q25= -8.3865 iqr= 11.0909 minimum= -25.02285 maximum= 19.34075
# no. of outlier in  var_176 is 40
# q75= 13.9313 q25= 9.808675 iqr= 4.122625000000001 minimum= 3.6247374999999975 maximum= 20.115237500000003
# no. of outlier in  var_177 is 3
# q75= 5.33875 q25= -7.3957 iqr= 12.734449999999999 minimum= -26.497374999999998 maximum= 24.440425
# no. of outlier in  var_178 is 43
# q75= 4.391125 q25= 0.625575 iqr= 3.7655499999999997 minimum= -5.02275 maximum= 10.039449999999999
# no. of outlier in  var_179 is 1509
# q75= 0.9962 q25= -6.6739 iqr= 7.6701 minimum= -18.17905 maximum= 12.50135
# no. of outlier in  var_180 is 34
# q75= 11.0113 q25= 9.0847 iqr= 1.9266000000000005 minimum= 6.194799999999999 maximum= 13.901200000000001
# no. of outlier in  var_181 is 66
# q75= 7.499175000000001 q25= -6.064425 iqr= 13.563600000000001 minimum= -26.409825 maximum= 27.844575000000003
# no. of outlier in  var_182 is 5
# q75= 12.127424999999999 q25= 5.4231 iqr= 6.704324999999999 minimum= -4.6333874999999995 maximum= 22.183912499999998
# no. of outlier in  var_183 is 23
# q75= 19.45615 q25= 5.6633 iqr= 13.792850000000001 minimum= -15.025975000000003 maximum= 40.145425
# no. of outlier in  var_184 is 43
# q75= -0.59065 q25= -7.36 iqr= 6.76935 minimum= -17.514025 maximum= 9.563375
# no. of outlier in  var_185 is 231
# q75= 11.1938 q25= 6.7152 iqr= 4.478599999999999 minimum= -0.0026999999999981483 maximum= 17.911699999999996
# no. of outlier in  var_186 is 446
# q75= -1.466 q25= -19.205125000000002 iqr= 17.739125 minimum= -45.813812500000004 maximum= 25.1426875
# no. of outlier in  var_187 is 3
# q75= 18.345225 q25= 12.501550000000002 iqr= 5.8436749999999975 minimum= 3.7360375000000055 maximum= 27.110737499999995
# no. of outlier in  var_188 is 23
# q75= 1.4829 q25= 0.0149 iqr= 1.4680000000000002 minimum= -2.1871000000000005 maximum= 3.6849000000000007
# no. of outlier in  var_189 is 15
# q75= 6.4062 q25= -0.058825 iqr= 6.465025 minimum= -9.7563625 maximum= 16.1037375
# no. of outlier in  var_190 is 163
# q75= 9.512525 q25= 5.1574 iqr= 4.355125 minimum= -1.3752874999999998 maximum= 16.045212499999998
# no. of outlier in  var_191 is 80
# q75= 2.9495 q25= 0.889775 iqr= 2.0597250000000003 minimum= -2.1998125 maximum= 6.039087500000001
# no. of outlier in  var_192 is 733
# q75= 6.2058 q25= 0.5846 iqr= 5.6212 minimum= -7.847199999999999 maximum= 14.637599999999999
# no. of outlier in  var_193 is 461
# q75= 20.396524999999997 q25= 15.6298 iqr= 4.766724999999997 minimum= 8.479712500000003 maximum= 27.546612499999995
# no. of outlier in  var_194 is 2
# q75= 0.8296 q25= -1.1707 iqr= 2.0003 minimum= -4.171150000000001 maximum= 3.8300500000000004
# no. of outlier in  var_195 is 132
# q75= 6.556725 q25= -1.946925 iqr= 8.50365 minimum= -14.7024 maximum= 19.3122
# no. of outlier in  var_196 is 0
# q75= 9.5933 q25= 8.2528 iqr= 1.3404999999999987 minimum= 6.2420500000000025 maximum= 11.604049999999997
# no. of outlier in  var_197 is 51
# q75= 18.064725 q25= 13.8297 iqr= 4.2350249999999985 minimum= 7.477162500000003 maximum= 24.417262499999996
# no. of outlier in  var_198 is 94
# q75= 4.8368 q25= -11.208475 iqr= 16.045275 minimum= -35.2763875 maximum= 28.9047125
# no. of outlier in  var_199 is 20

# %%
print('no. of outliers=',outliers)
# Out:
# no. of outliers= 26536

# %%
for i in columns:
    q75=np.percentile(train[i],75)
    q25=np.percentile(train[i],25)
    iqr=q75-q25
    minimum=q25-(iqr*1.5)
    maximum=q75+(iqr*1.5)
    train[i].loc[train[i]>maximum]=np.nan
    train[i].loc[train[i]<minimum]=np.nan
# Out:
# C:\Users\My guest\Anaconda3\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
#train_input['var_0'].loc[train_input['var_0']>maximum]=np.nan
print('no. of nans made out of outliers=',train.isna().sum().sum())
# Out:
# no. of nans made out of outliers= 26536

# %%
#removing nans and hence removing all outliers
train=train.dropna()
train.isna().sum().sum()
# Out:
# 0

# %%
train.shape
# Out:
# (175104, 201)

# %%
# checking the training data for imbalance 
count_classes = pd.value_counts(train.target)
print(count_classes)
count_classes.plot(kind= 'bar',rot=1)
# Out:
# 0    157999
# 1     17105
# Name: target, dtype: int64

# %%
# Data to plot
labels = 'zeros', 'ones'
sizes = [157999,17105]
colors = ['gold', 'yellowgreen']
explode = (0.1, 0)  # explode 1st slice

# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.show()

# %%
sns.heatmap(train.corr())
svm=sns.heatmap(train.corr())

figure = svm.get_figure()    
figure.savefig('svm_conf.png', dpi=400)

# %%
f = plt.figure(figsize=(19, 15))
plt.matshow(train.corr(), fignum=f.number)
plt.xticks(range(train.shape[1]), train.columns, fontsize=14, rotation=45)
plt.yticks(range(train.shape[1]), train.columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix', fontsize=16);
plt.savefig('correlation matrix.png')

# %%
plt.matshow(train.corr())
plt.show()
plt.savefig('corr.png')

# %%
rs = np.random.RandomState(0)
corr = train.corr()
corr.style.background_gradient(cmap='coolwarm')
plt.savefig('coolwarm_corr.png')

# %%
# putting all the df colname in a list
traincols = list(train.columns)

# exculdig target and index columns
variables = traincols[2:]

# splitting the list every n elements:
n = 10
chunks = [variables[x:x + n] for x in range(0, len(variables), n)]

# %%
# displaying a boxplot every n columns:
for i in chunks:
    plt.show(train.boxplot(column = i, sym='k.', figsize=(10,5)))

# %%
train.columns
# Out:
# Index(['target', 'var_0', 'var_1', 'var_2', 'var_3', 'var_4', 'var_5', 'var_6',
#        'var_7', 'var_8',
#        ...
#        'var_190', 'var_191', 'var_192', 'var_193', 'var_194', 'var_195',
#        'var_196', 'var_197', 'var_198', 'var_199'],
#       dtype='object', length=201)

# %%
# split the data into train and test
X_train, X_test, y_train, y_test = train_test_split(train.drop('target',axis=1),train.target,test_size=0.3)
print(X_train.shape,X_test.shape,y_train.shape,y_test.shape)
# Out:
# (122572, 200) (52532, 200) (122572,) (52532,)

# %%
y_train.shape
# Out:
# (122572,)

# %%
# checking the training data for imbalance 
count_classes = pd.value_counts(y_train)
print(count_classes)
count_classes.plot(kind= 'bar',rot=1)
# Out:
# 0    110632
# 1     11940
# Name: target, dtype: int64

# %%
# Data to plot
labels = 'zeros', 'ones'
sizes = [110632,11940]
colors = ['gold', 'yellowgreen']
explode = (0.1, 0)  # explode 1st slice

# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.show()

# %%
# checking the training data for imbalance 
count_classes = pd.value_counts(y_test)
print(count_classes)
count_classes.plot(kind= 'bar',rot=1)
# Out:
# 0    47367
# 1     5165
# Name: target, dtype: int64

# %%
# Data to plot
labels = 'zeros', 'ones'
sizes = [47367,5165]
colors = ['gold', 'yellowgreen']
explode = (0.1, 0)  # explode 1st slice

# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.show()

# %%
# handling imbalance training  data
#HANDLING IMBALANCED DATA BY OVER SAMPLING
os =  RandomOverSampler(ratio=1)
X_train_res, y_train_res = os.fit_sample(X_train,y_train)
X_train_res.shape,y_train_res.shape
print(X_train_res.shape,y_train_res.shape)
print('Original dataset shape {}'.format(Counter(y_train)))
print('Resampled dataset shape {}'.format(Counter(y_train_res)))
# Out:
# (221264, 200) (221264,)
# Original dataset shape Counter({0: 110632, 1: 11940})
# Resampled dataset shape Counter({0: 110632, 1: 110632})

# %% [markdown]
# #modeling using k fold cross validation function

# %%
# Xgb model
#cross_val_score( xgb.XGBClassifier(),X_train_res, y_train_res,cv=3)

# %%
# 35 minutes

# %%
#decision tree
#cross_val_score(tree.DecisionTreeClassifier(),X_train_res,y_train_res,cv=3)

# %%
#random forest
cross_val_score(RandomForestClassifier(n_estimators=20),X_train_res,y_train_res,cv=3).mean()
# Out:
# 0.9984950175930708

# %%
#naive bayes
cross_val_score(GaussianNB(),X_train_res,y_train_res,cv=3).mean()
# Out:
# 0.8087398025522221

# %%
#logistic regression
#cross_val_score(LogisticRegression(),X_train_res,y_train_res,cv=3)

# %%
#sgd
#cross_val_score(SGDClassifier(),X_train_res,y_train_res,cv=3)

# %%
#from lightgbm import LGBMClassifier
cross_val_score(LGBMClassifier(),X_train_res,y_train_res,cv=3).mean()
# Out:
# 0.8534239864549845

# %%
#from sklearn.model_selection import RandomizedSearchCV
# Create the parameter grid based on the results of random search 
#param_grid = {
    #'bootstrap': [True],
   # 'max_depth': [80, 90, 100, 110],
   # 'max_features': [2, 3],
   # 'min_samples_leaf': [3, 4, 5],
   # 'min_samples_split': [8, 10, 12],
   # 'n_estimators': [100, 200, 300, 1000]
#}
# Create a based model
#rf = RandomForestClassifier()
# Instantiate the grid search model
#random_search = RandomizedSearchCV(estimator = rf, param_distributions= param_grid, 
                          cv = 3, n_jobs = -1, verbose = 2)
# Fit the grid search to the data
#rf_random=random_search.fit(X_train_res,y_train_res)
# Out:
#   File "<ipython-input-41-6e68e8f9d36e>", line 15
#     cv = 3, n_jobs = -1, verbose = 2)
#     ^
# IndentationError: unexpected indent

# %%
# Fit the random search model
#rf_random.best_params_

# %% [markdown]
# # model implementation usin random forest

# %%
model_rf = RandomForestClassifier(n_estimators=20)

# %%
model_rf.fit(X_train_res,y_train_res)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=20,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
model_rf.score(X_test,y_test)
# Out:
# 0.9015457245107744

# %%
prediction=model_rf.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
CM = confusion_matrix(y_test,prediction)
CM =pd.crosstab(y_test,prediction)
CM
# Out:
# col_0       0   1
# target
# 0       47348  19
# 1        5153  12

# %%
from sklearn.metrics import accuracy_score 
accuracy_score(y_test,prediction)*100
# Out:
# 90.15457245107744

# %%
TN=CM.iloc[0,0]
FN=CM.iloc[1,0]
TP=CM.iloc[1,1]
FP=CM.iloc[1,0]

# %%
#false nagative rate
FN*100/(FN+TP)
# Out:
# 99.7676669893514

# %%
# FALSE POSITIVE RATE
FP*100/(TN+FP)
# Out:
# 9.815051141883012

# %%
#RECALL
TP*100/(TP+FN)
# Out:
# 0.23233301064859632

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import roc_curve, auc
fpr, tpr, thresholds = roc_curve(y_test,prediction)
roc_auc = auc(fpr,tpr)
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b',label='AUC = %0.3f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.1,1.0])
plt.ylim([-0.1,1.01])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
plt.savefig('auc_rf')

# %% [markdown]
# # implementation using NAives bayes

# %%
model=GaussianNB()

# %%
model.fit(X_train_res,y_train_res)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
prediction=model.predict(X_test)

# %%
model.score(X_test,y_test)
# Out:
# 0.810972359704561

# %%
from sklearn.metrics import confusion_matrix
CM = confusion_matrix(y_test,prediction)
CM =pd.crosstab(y_test,prediction)
CM
# Out:
# col_0       0     1
# target
# 0       38503  8864
# 1        1066  4099

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import roc_curve, auc
fpr, tpr, thresholds = roc_curve(y_test,prediction)
roc_auc = auc(fpr,tpr)
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b',label='AUC = %0.3f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.1,1.0])
plt.ylim([-0.1,1.01])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
plt.savefig('auc_nb')

# %% [markdown]
# # implementation using light gbm

# %%
model=LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
               importance_type='split', learning_rate=0.1, max_depth=-1,
               min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
               n_estimators=1000, n_jobs=-1, num_leaves=31, objective=None,
               random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
               subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
model.fit(X_train_res,y_train_res)
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=1000, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#                subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
model.score(X_test,y_test)
# Out:
# 0.9071042412243966

# %%
prediction=model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
CM = confusion_matrix(y_test,prediction)
CM =pd.crosstab(y_test,prediction)
CM
# Out:
# col_0       0     1
# target
# 0       45077  2290
# 1        2590  2575

# %%
from sklearn.metrics import accuracy_score 
accuracy_score(y_test,prediction)*100
# Out:
# 90.71042412243966

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import roc_curve, auc
fpr, tpr, thresholds = roc_curve(y_test,prediction)
roc_auc = auc(fpr,tpr)
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b',label='AUC = %0.3f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.1,1.0])
plt.ylim([-0.1,1.01])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
plt.savefig('lightgmb_auc')

# %%
test.drop('target',axis=1,inplace=True)
prediction=model.predict(test)

# %%
test['target']=pd.DataFrame(prediction)

# %%
# checking the training data for imbalance 
count_classes = pd.value_counts(test.target)
print(count_classes)
count_classes.plot(kind= 'bar',rot=1)
# Out:
# 0    176461
# 1     23539
# Name: target, dtype: int64

# %% [markdown]
# # predictionn the target value for test data set value using  naive bayes

# %%
prediction=model.predict(test)
prediction.shape
# Out:
# (200000,)

# %%
test['target']=pd.DataFrame(prediction)

# %%
count_classes = pd.value_counts(test.target)
print(count_classes)
count_classes.plot(kind= 'bar',rot=1)
# Out:
# 0    149310
# 1     50690
# Name: target, dtype: int64

# %%
# target column is the solution of required problem statment
